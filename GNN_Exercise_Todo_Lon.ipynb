# %% [markdown]
# # Giới thiệu

# %% [markdown]
# Trong bài tập này, chúng ta sẽ thực hành implement GCN dựa trên paper [GCN](https://arxiv.org/pdf/1609.02907.pdf).
#
# - Những bước cần phải làm:
#   1.   Đọc data từ file và lưu về dạng mô hình có thể xử lý
#   2.   Tạo Node Embedding sử dụng thuật toán DeepWalk. Từ đó, ta có thể tạo được feature embedding
#   3.   Tạo adjacency matrix
#   4.   Sử dụng adjacency matrix và node embedding để làm đầu vào cho mô hình GCN
#   5.   Implement mô hình GCN với đầu ra là bài toán  classification.
#
# - Mô tả dataset: Bộ dataset này miêu tả một mạng xã hội, với các node là người trong mạng đó. Mỗi người có một role, và một community mà ngừoi đó thuộc về
#   1.   ex_edgelist.txt: Một danh sách miêu tả node nào được nối với nhau => Ta có thể tạo ma trận kề từ file này
#   2.   ex_attributes.csv: Danh sách các feature của từng node. Mỗi node  sẽ có 2 feature, "role" và "community"
#
# - Mục tiêu bài tập:
#   Sử dụng lớp GCN như một classifier để quyết định "member" trong mạng thuộc về community "administrator" hay "instructor"
#
# - Note:
#   1. Điền code vào phần được đánh dấu là bài tập, các phần khác được implement sẵn để các bạn hiểu được flow tổng thể của một bài toán sử dụng GNN
#   2. Sử dụng "Table of contents" để tìm phần "bài tập" một cách nhanh hơn

# %% [markdown]
# # Bài tập

# %% [markdown]
# ## Packages

# %%
import torch
import torch.nn as nn
import numpy as np
import networkx as nx
import torch.optim as optim
import torch.nn.functional as F
import pandas as pd
import random

# %%
# set seed cho random 
torch.manual_seed(49)
random.seed(49)
np.random.seed(49)

# %% [markdown]
# ## Tải dữ liệu và các đặt các packages cần thiết

# %%
# !gdown --id "18NI2HRLStk5hwuE7B-woIlcFKJHyKK5I"
# !unrar x -Y "/content/exercise.rar" -d "/content/"
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=18NI2HRLStk5hwuE7B-woIlcFKJHyKK5I
# To: /workspace/nabang1010/LBA_VAIPE/GNN/Multi_Label_Image_Recognition_with_Graph_Convolutional_Networks/exercise.rar
# 100%|██████████████████████████████████████| 1.06k/1.06k [00:00<00:00, 1.41MB/s]
# /bin/bash: unrar: command not found

# %% [markdown]
# ### **Giới thiệu lại về đồ thị**
#
# Đồ thị là một cấu trúc dữ liệu có thể được biểu diễn dưới dạng **G=<V,E>**, với **V** là tập các đỉnh, **E** là tập cạnh nối các đỉnh

# %% [markdown]
# ### Giới thiệu thư viện

# %% [markdown]
# **Networkx** là một package trong python để tạo, visualize và thao tác trên các mạng phức tạp
#
# Link: [Networkx](https://networkx.org).
#
# Các datastructure trong networkx bao gồm:
#   1.   Graph: Normal Graph (vô hướng)
#   2.   DiGraph: Directed Graph (có hướng)
#   3.   Multigraph: Đa đồ thị

# %%
# Đọc Graph từ file  
G_inp = nx.read_edgelist("./ex/ex_edgelist.txt", create_using=nx.DiGraph())
# Tạo graph 
## Graph 
G  = nx.Graph()
## DiGraph 
DiG = nx.DiGraph()
## MultiGraph 
MG = nx.MultiGraph()
## Tạo graph sử dụng adjacency list 
G_adj = nx.Graph({0: (1, 2), 1: (0, 2), 2: (0, 1)})  
# Các thao tác trên Graph 
## Thêm đỉnh 
G.add_node(1) # thêm đỉnh 
G.add_nodes_from([2,3,4]) # thêm một list các đỉnh 
G.add_nodes_from([ # thêm đỉnh kèm theo attribute 
    (4, {"color": "red"}),
    (5, {"color": "green"}),
])
H = nx.path_graph(10) # thêm đỉnh từ một graph khác 
G.add_nodes_from(H)
## Thêm cạnh 
G.add_edge(1, 2) # thêm từng cạnh 
G.add_edges_from([(1, 2), (1, 3)]) # thêm một list các cạnh 
## Xoá 
G.remove_node(2)  # Xoá đỉnh   
G.remove_edge(1,3) # Xoá cạnh 
# Vẽ graph 
nx.draw(G_inp)

# %% [markdown]
# ### Visualize dữ liệu

# %%
# Ta xem tiết file ex_attribute.csv để hiểu tính chất của các node 
edge_attr = pd.read_csv("./ex/ex_attributes.csv")
edge_attr.tail()
# Out:
#     node        role   community
# 29    29      Member  Instructor
# 30    30      Member  Instructor
# 31    31      Member  Instructor
# 32    32      Member  Instructor
# 33    33  Instructor  Instructor

# %%
# Ta đọc xem mỗi community có số lượng bao nhiêu node 
edge_attr.groupby(["community"]).count()
# Out:
#                node  role
# community
# Administrator    17    17
# Instructor       17    17

# %%
# Liệt kê danh sách các community 
lst_commu = list(set(edge_attr["community"].tolist()))
print(lst_commu)
# Out:
# ['Instructor', 'Administrator']

# %%
# Liệt kê danh sách các role có thể 
lst_role = list(set(edge_attr["role"].tolist()))
print(lst_role)
# Out:
# ['Instructor', 'Administrator', 'Member']

# %% [markdown]
# ## Tiện ích: Xử lý dữ liệu

# %% [markdown]
# ### [TO DO 1] Xây dựng đồ thị và ma trận kề
# - Tạo graph với node có attribute tương ứng
# - Tạo ma trận kề  từ file ex_edgelist.txt
#   1. Shape: (node, node)
#   2. Type: array (numpy)

# %%
# Todo
def create_graph_with_attributes(edgelist_filepath, attributes_filepath):
  '''
    Description: Tạo đồ thị vô hướng với các node chứa attribute đọc từ file attribute 
    Input: File các cạnh, file attribute của từng node 
    Output: graph 
  '''

  # TODO: Tạo đồ thị vô hướng sử dụng nx.read_edgelist
  graph = nx.read_edgelist(edgelist_filepath, create_using=nx.Graph())



  # TODO: Đọc file attribute 
  attributes = pd.read_csv(attributes_filepath)

  
  # Tạo một dictionary với key là node_id, value là value của attribute 
  att_values = {a:{'role':b[0],'community':b[1]} for a,b in enumerate(attributes.values)}
  # TODO: Set attribute cho các node tương ứng sử dụng nx.set_node_attributes
  nx.set_node_attributes(graph, att_values)
  

  return graph

def create_adj_matrix(graph):
  '''
    Description: Tạo ma trận kề sử dụng hàm nx.to_numpy_matrix
    Input: graph
    Output: numpy array 
  '''
  # Sử dụng nx.to_numpy_matrix để chuyển từ nx sang np
  graph_np = nx.to_numpy_matrix(graph)
  return graph_np

# %% [markdown]
# ### Xây dựng Node embedding

# %% [markdown]
# #### Lý thuyết:
#
# **Graph Embedding là gì?**
#
# Để  biểu diễn Graph, chúng ta có 2 hướng tiếp cận chính:
#
# *   Hướng đầu tiên sử dụng mô hình graph truyền thống với các node và cạnh, các node được nối với nhau bằng một cạnh được gọi là hàng xóm của nhau (neighbour)
# *   Tuy vậy, nếu biểu diễn dưới dạng này, các mô hình học máy hay học sâu không thể học được. Do đó, người ta nghĩ ra việc chuyển mô hình graph về dạng embedding domain, với mỗi node được biểu diễn dưới dạng một continuous vector.
# *   Node embedding sẽ có chiều là [số node, len(feature_vector)]
#
# **Hướng tiếp cận**
#
# Để xây dựng embedding vector cho graph, trước hết ta cần trả lời 2 câu hỏi:
#
# *   Ta cần giữ các thuộc tính gì khi xây dựng embedding
# *   Làm thế nào để xây dựng nên embedding đó?
#
# Về câu hỏi thứ nhất, một số các nghiên cứu đã được thực hiện để giải quyết các bài toán liên quan đến:
#
# 1.   Lưu trữ thông tin của node hàng xóm [Link](https://arxiv.org/abs/1403.6652)
# 2.   Lưu trữ thông tin về kiến trúc của node [Link](https://arxiv.org/abs/1704.03165)
# 3.   Lưu trữ thông tin về trạng thái của node [Link](https://arxiv.org/abs/1710.07266)
# 4.   Lưu trữ thông tin về community [Link](https://www.aaai.org/ocs/index.php/AAAI/AAAI17/paper/download/14589/13763)
#
#
# Còn về câu hỏi thứ hai, một framework chung đã được thiết kế như hình vẽ dưới đây:
#
# ![Screenshot from 2021-10-21 10-38-47.png](data:image/png;base64,...)

# %% [markdown]
# 1.   **Mapping function**: Map từ graph domain sang embedding domain
# 2.   **Information extractor**: Lấy những thông tin quan trọng *I* mà ta muốn giữ từ graph-domain
# 3.   **Reconstructor**: Từ embedding domain, ta dùng reconstructor này để dựng lại các thông tin được trích rút trong phase 2, ta gọi graph information được dựng lại này là *I'*
# 4.   **Objective**: Đầu vào của objective function là thông tin gốc *I* và thông tin dựng lại *I'*. Ta muốn từ đây có thể minimize sự sai khác giữa *I* và *I'* trong quá trình học bằng cách thay đổi các bộ tham số của reconstructor
#
# **Mapping function** dưới dạng đơn giản nhất là: table lookup
#
# Còn với **information extractor**, các thuật toán thường được xây dựng trên cơ chế random-walk based - DeepWalk
#
# Tiếp theo chúng ta sẽ bắt tay xây dựng một graph embedding cơ bản

# %% [markdown]
# #### [TO DO 2] Cách 1: Node embedding cơ bản chỉ sử dụng tính chất về khoảng cách
#
# Ta thử tạo một embedding vector cơ bản với:
#   1. Shape: (số lượng đỉnh, số feature)
#   2. Type: np.array
#   3. Input feature: Bao gồm 2 phần tử [shortest_path(cur_node, 0), shortest_path(cur_node, 33)]

# %%
def create_node_embedding_simple(graph):
  # Tạo np.array từ graph 
  A = create_adj_matrix(graph)
  # print(A)
  
  # Tạo một ma trận có kích thước [số lượng đỉnh, 2]
  input_features = torch.zeros((len(A), 2))
  
  # Sử dụng nx.shortest_length của từng node tới node 33
  node_distance_instructor = nx.shortest_path_length(graph, target='33')
  
  # Sử dụng nx.shortest_length của từng node tới node 0
  node_distance_administrator = nx.shortest_path_length(graph, target='0')
  
  # Với từng node trong graph, gán X[node] = [khoảng cách đến node 33, khoảng cách đến node 0]
  for node in graph.nodes():
    input_features[int(node)][0] = node_distance_instructor[node]
    input_features[int(node)][1] = node_distance_administrator[node]

  return input_features

# %%
g  = create_graph_with_attributes('./ex/ex_edgelist.txt','./ex/ex_attributes.csv')
ne_simple = create_node_embedding_simple(g)
ne_simple
# Out:
# tensor([[2., 0.],
#         [2., 1.],
#         [2., 1.],
#         [2., 1.],
#         [3., 1.],
#         [3., 1.],
#         [3., 1.],
#         [3., 1.],
#         [1., 1.],
#         [1., 2.],
#         [3., 1.],
#         [3., 1.],
#         [3., 1.],
#         [1., 1.],
#         [1., 3.],
#         [1., 3.],
#         [4., 2.],
#         [3., 1.],
#         [1., 3.],
#         [1., 1.],
#         [1., 3.],
#         [3., 1.],
#         [1., 3.],
#         [1., 3.],
#         [2., 2.],
#         [2., 2.],
#         [1., 3.],
#         [1., 2.],
#         [1., 2.],
#         [1., 3.],
#         [1., 2.],
#         [1., 1.],
#         [1., 2.],
#         [0., 2.]])

# %% [markdown]
# #### Cách 2: Sử dụng các Node Embedding phức tạp hơn để giữ tính chất co-occurrence

# %%
from joblib import Parallel, delayed
import random
import itertools
import numpy as np
from gensim.models import Word2Vec

# %%
def partition_num(num, workers):
    if num % workers == 0:
        return [num//workers]*workers
    else:
        return [num//workers]*workers + [num % workers]

# %% [markdown]
# ##### DeepWalk
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Class **RandomWalker** được sử dụng như Information Extractor
#
# Về cơ bản, ta sẽ sử dụng hàm simulate_walks để tạo ra n=num_walks số lượt đi ngẫu nhiên giữa các node, với mỗi lượt sẽ đi qua độ dài=walk_length nodes
#
# Mỗi lượt đi được coi như một câu hoàn chỉnh, với các từ là các node đã được đi qua.
#
# Với RandomWalk, ta coi mỗi node neighbour đều có xác suất là 1/p được đi đến, với p là số lượng neighbour của node đang xét

# %%
class RandomWalker:
  def __init__(self, G, num_walks, walk_length):
      """
      :param G: Graph
      :param num_walks: a number of walks per vertex
      :param walk_length: Length of a walk. Each walk is considered as a sentence
      """
      self.G = G
      self.num_walks = num_walks
      self.walk_length = walk_length


  def deepwalk_walk(self, start_node):
      """
      :param start_node: Starting node of a walk
      """
      walk = [start_node]
      while len(walk) < self.walk_length:
          cur = walk[-1]
          # Check if having any neighbors at the current node
          cur_nbrs = list(self.G.neighbors(cur))
          if len(cur_nbrs) > 0:
              # Random walk with the probability of 1/d(v^t). d(v^t) is the node degree
              walk.append(random.choice(cur_nbrs))
          else:
              break
      return walk


  def simulate_walks(self, workers=1, verbose=0):
      """
      :param workers: a number of workers running in parallel processing
      :param verbose: progress bar
      """
      G = self.G
      nodes = list(G.nodes())
      results = Parallel(n_jobs=workers, verbose=verbose)(
          delayed(self._simulate_walks)(nodes) for num in
          partition_num(self.num_walks, workers))
      walks = list(itertools.chain(*results))
      return walks

  # INFORMATION EXTRACTOR
  def _simulate_walks(self, nodes):
      walks = []
      # Iterate all walks per vertex
      for _ in range(self.num_walks):
          random.shuffle(nodes)
          # Iterate all nodes in a walk
          for v in nodes:
            walks.append(self.deepwalk_walk(start_node=v))
      return walks

# %% [markdown]
# Sau đó ta cho tập các lượt đi qua mô hình Word2Vec để học được node embedding
#
# Chi tiết xem tại: [Word2Vec](https://radimrehurek.com/gensim/auto_examples/tutorials/run_word2vec.html)

# %%
class DeepWalk:
    def __init__(self, graph, walk_length, num_walks, workers=1):

        self.graph = graph
        self.w2v_model = None
        self._embeddings = {}

        self.walker = RandomWalker(graph, num_walks=num_walks, walk_length=walk_length)
        self.sentences = self.walker.simulate_walks(workers=workers, verbose=1)

    def train(self, embed_size=128, window_size=5, workers=1, iter=5, **kwargs):

        kwargs["sentences"] = self.sentences
        kwargs["min_count"] = kwargs.get("min_count", 0)
        kwargs["vector_size"] = embed_size
        kwargs["sg"] = 1  # skip gram
        kwargs["hs"] = 1  # deepwalk use Hierarchical Softmax
        kwargs["workers"] = workers
        kwargs["window"] = window_size
        # kwargs["iter"] = iter


        print("Learning embedding vectors...")
        # model = Word2Vec(vector_size= window_size,  ) # Pay attention here
        model = Word2Vec(**kwargs)
        print("Learning embedding vectors done!")

        self.w2v_model = model
        return model

    def get_embeddings(self):
        # Lấy embedding của từng node, sau đó sắp xếp theo thứ tự node rồi stack thành 2D matrix 
        if self.w2v_model is None:
            print("model not train")
            return {}
        self._embeddings = {}
        for word in self.graph.nodes():
          self._embeddings[word] = self.w2v_model.wv[word]

        lst_arr = []
        for i in range(len(self._embeddings.keys())):
          # print('Step {}: {}'.format(i, self._embeddings[str(i)]))
          lst_arr.append(self._embeddings[str(i)])
        return torch.from_numpy(np.stack(lst_arr))

# %%
model = DeepWalk(g, walk_length=20, num_walks=80, workers=1) #init model
model.train(window_size=5, iter=3) # train model
ne_dw = model.get_embeddings() # get node embedding using deepwalk
ne_dw
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
# Learning embedding vectors...
# Learning embedding vectors done!
# tensor([[ 0.0836,  0.0474,  0.3516,  ..., -0.2380, -0.2181, -0.0444],
#         [-0.0160,  0.0143,  0.1745,  ..., -0.1863, -0.1256, -0.1594],
#         [-0.0033, -0.0615,  0.0124,  ..., -0.2205, -0.0973,  0.1077],
#         ...,
#         [-0.1600,  0.0409,  0.0909,  ..., -0.2928,  0.0684,  0.0416],
#         [-0.0058, -0.0216, -0.0051,  ..., -0.0669, -0.0389,  0.0897],
#         [ 0.0166, -0.0825, -0.0048,  ..., -0.1204, -0.0837,  0.1169]])

# %% [markdown]
# ## Mô hình: Graph Convolutional Networks

# %% [markdown]
# ![GCN.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2021-10-29 22-18-54.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2021-10-29 22-19-02.png](data:image/png;base64,...)

# %% [markdown]
# ### [TO DO 3] Viết hàm tính A_hat trong class GCN_layer

# %%
from torch.nn.parameter import Parameter

class GCN_layer(nn.Module):
    def __init__(self, inputs_shape, outputs_shape):
        super(GCN_layer, self).__init__()
        # Khai báo một trainable matrix cho W  
        self.W=Parameter(torch.rand(inputs_shape,outputs_shape),requires_grad=True)
        # Khai báo một trainable matrix cho b
        self.bias = Parameter(torch.rand(outputs_shape),requires_grad=True)
        
    def forward(self, adj_matrix, input_features):
        # Khai báo một torch tensor sử dụng torch.from_numpy với kiểu Long 
        A= torch.from_numpy(adj_matrix).long()
        
        # Tính ma trận I là identity_matrix cùng chiều với adj_matrix sử dụng torch.eye 
        I= torch.eye(A.shape[0])
        
        # Tính A_hat = A + I
        A_hat= A+I
        
        # Tính D = tổng các hàng ngang của ma trận A sử dụng torch.sum
        D = torch.sum(A_hat, dim=1)
        
        # Tính D^-1/2 sử dụng torch.pow, sau đó sử dụng torch.diag để tạo ma trận chéo  
        D_norm = torch.diag(torch.pow(D, -0.5))
        
        # Tính A_hat = D^-1/2 * A_hat * D^-1/2 sử dụng torch.mm 
        A_hat = torch.mm(torch.mm(D_norm, A_hat), D_norm)
        
        # Nhân A_hat với input
        aggregate= torch.mm(A_hat, input_features)

        # Nhân kết qua của A_hat * input với W, sau đó cộng với bias 
        propagate= torch.mm(aggregate, self.W) + self.bias

        return propagate

# %% [markdown]
# ### [TO DO 4] Implement "forward" function trong class "GCN".

# %%
class GCN(nn.Module):
    def __init__(self,inputs_shape,outputs_shape,n_classes,activation='Relu'):
        super(GCN, self).__init__()

        self.layer1=GCN_layer(inputs_shape,outputs_shape)
        self.layer2=GCN_layer(outputs_shape,n_classes)
        self.activation=nn.ReLU()
        self.softmax=nn.Softmax()
    
    def forward(self,adj_matrix,input_features):
      # Solution: Follow method in the image above:
      # Step 1: Put adj_matrix and input_features into self.layer1
      x= self.layer1(adj_matrix,input_features)
      
      # Step 2: Put the output of step 1 through activation "relu"
      x= self.activation(x)
      
      # Step 3: Put the output of step 2 through self.layer2
      x= self.layer2(adj_matrix,x)
      
      # Step 4: Put the output of step 3 through softmax
      x= self.softmax(x)
      return x

# %%
import torch
from sklearn.metrics import classification_report
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import networkx as nx


class Trainer():
    def __init__(self,model,optimizer,loss_function,epochs,adj_matrix,input_features):
        
        self.model=model
        self.optimizer=optimizer
        self.loss_function=loss_function
        self.epochs=epochs
        self.adj_matrix = adj_matrix
        self.input_features = input_features
        
    def train(self,X_train,Y_train):
        y_train=torch.from_numpy(Y_train.astype(int)).type(torch.LongTensor)
        tot_loss=0.0
        all_preds=[]

        # Viết hàm train 
        for t in range(self.epochs):
            epoch_loss = 0.0

            y_pred=self.model(self.adj_matrix, self.input_features)
            all_preds.append(y_pred)
            loss = self.loss_function(y_pred[X_train], y_train)
            self.optimizer.zero_grad()
            epoch_loss+=loss
            tot_loss+=loss            # trả về kết quả dự đoán 

            loss.backward()
            self.optimizer.step()

            print(str(t),'epoch_loss:'+str(epoch_loss),'total loss:'+str(tot_loss))

        self.all_preds=all_preds
    
    def test(self,X_test,Y_test):
        self.model.eval()
        y_test=torch.from_numpy(Y_test.astype(int)).type(torch.LongTensor)
        y_pred=self.all_preds[-1]  # preds of last epoch
        loss_test = self.loss_function(y_pred[X_test],y_test)
        print('validation loss is equal to: '+str(loss_test))
    
    def visualize_classification(self,graph,Y_test,classification):
        last_epoch = self.all_preds[self.epochs-1].detach().numpy() # get outputs of last epoch
        predicted_class = np.argmax(last_epoch, axis=-1) # take the unit with the higher probability
        color = np.where(predicted_class==0, 'c', 'r')
        pos = nx.kamada_kawai_layout(graph)
        nx.draw_networkx(graph, pos, node_color=color, with_labels=True, node_size=300)
        if classification==True:
            print(classification_report(predicted_class[1:-1],Y_test))

# %% [markdown]
# ## Thực thi GCN

# %%
model_dw = DeepWalk(g, walk_length=20, num_walks=80, workers=1) #init model
model_dw.train(window_size=5, iter=3) # train model
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
# Learning embedding vectors...
# Learning embedding vectors done!

# %%
graph=create_graph_with_attributes('./ex/ex_edgelist.txt','./ex/ex_attributes.csv')
adj_matrix = create_adj_matrix(graph)
ne_simple = create_node_embedding_simple(graph)
ne_dw = model_dw.get_embeddings()

# %%
X_train = np.load("./ex/X_train.npy")
Y_train = np.load("./ex/Y_train.npy")
X_test = np.load("./ex/X_test.npy")
Y_test = np.load("./ex/Y_test.npy")

# %% [markdown]
# ### Kiểm thử với embedding đơn giản

# %%
model=GCN(inputs_shape=ne_simple.shape[1],outputs_shape=4,n_classes=2)
trainer = Trainer(
    model,
    optimizer = optim.Adam(model.parameters(), lr=0.01),
    loss_function=F.cross_entropy,
    epochs=250,
    adj_matrix=adj_matrix,
    input_features=ne_simple
)

trainer.train(X_train,Y_train)
trainer.test(X_test,Y_test)
trainer.visualize_classification(graph,Y_test,classification=True)
# Out:
# /root/anaconda3/envs/mlgcn/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 0 epoch_loss:tensor(0.6429, grad_fn=<AddBackward0>) total loss:tensor(0.6429, grad_fn=<AddBackward0>)
# 1 epoch_loss:tensor(0.6382, grad_fn=<AddBackward0>) total loss:tensor(1.2811, grad_fn=<AddBackward0>)
# 2 epoch_loss:tensor(0.6337, grad_fn=<AddBackward0>) total loss:tensor(1.9148, grad_fn=<AddBackward0>)
# 3 epoch_loss:tensor(0.6292, grad_fn=<AddBackward0>) total loss:tensor(2.5440, grad_fn=<AddBackward0>)
# 4 epoch_loss:tensor(0.6246, grad_fn=<AddBackward0>) total loss:tensor(3.1686, grad_fn=<AddBackward0>)
# 5 epoch_loss:tensor(0.6199, grad_fn=<AddBackward0>) total loss:tensor(3.7885, grad_fn=<AddBackward0>)
# 6 epoch_loss:tensor(0.6151, grad_fn=<AddBackward0>) total loss:tensor(4.4036, grad_fn=<AddBackward0>)
# 7 epoch_loss:tensor(0.6100, grad_fn=<AddBackward0>) total loss:tensor(5.0136, grad_fn=<AddBackward0>)
# 8 epoch_loss:tensor(0.6049, grad_fn=<AddBackward0>) total loss:tensor(5.6185, grad_fn=<AddBackward0>)
# 9 epoch_loss:tensor(0.5995, grad_fn=<AddBackward0>) total loss:tensor(6.2180, grad_fn=<AddBackward0>)
# 10 epoch_loss:tensor(0.5940, grad_fn=<AddBackward0>) total loss:tensor(6.8120, grad_fn=<AddBackward0>)
# 11 epoch_loss:tensor(0.5882, grad_fn=<AddBackward0>) total loss:tensor(7.4002, grad_fn=<AddBackward0>)
# 12 epoch_loss:tensor(0.5823, grad_fn=<AddBackward0>) total loss:tensor(7.9825, grad_fn=<AddBackward0>)
# 13 epoch_loss:tensor(0.5762, grad_fn=<AddBackward0>) total loss:tensor(8.5587, grad_fn=<AddBackward0>)
# 14 epoch_loss:tensor(0.5699, grad_fn=<AddBackward0>) total loss:tensor(9.1286, grad_fn=<AddBackward0>)
# 15 epoch_loss:tensor(0.5634, grad_fn=<AddBackward0>) total loss:tensor(9.6920, grad_fn=<AddBackward0>)
# 16 epoch_loss:tensor(0.5566, grad_fn=<AddBackward0>) total loss:tensor(10.2486, grad_fn=<AddBackward0>)
# 17 epoch_loss:tensor(0.5497, grad_fn=<AddBackward0>) total loss:tensor(10.7983, grad_fn=<AddBackward0>)
# 18 epoch_loss:tensor(0.5426, grad_fn=<AddBackward0>) total loss:tensor(11.3409, grad_fn=<AddBackward0>)
# 19 epoch_loss:tensor(0.5353, grad_fn=<AddBackward0>) total loss:tensor(11.8762, grad_fn=<AddBackward0>)
# 20 epoch_loss:tensor(0.5278, grad_fn=<AddBackward0>) total loss:tensor(12.4041, grad_fn=<AddBackward0>)
# 21 epoch_loss:tensor(0.5202, grad_fn=<AddBackward0>) total loss:tensor(12.9243, grad_fn=<AddBackward0>)
# 22 epoch_loss:tensor(0.5125, grad_fn=<AddBackward0>) total loss:tensor(13.4368, grad_fn=<AddBackward0>)
# 23 epoch_loss:tensor(0.5046, grad_fn=<AddBackward0>) total loss:tensor(13.9414, grad_fn=<AddBackward0>)
# 24 epoch_loss:tensor(0.4966, grad_fn=<AddBackward0>) total loss:tensor(14.4380, grad_fn=<AddBackward0>)
# 25 epoch_loss:tensor(0.4886, grad_fn=<AddBackward0>) total loss:tensor(14.9266, grad_fn=<AddBackward0>)
# 26 epoch_loss:tensor(0.4806, grad_fn=<AddBackward0>) total loss:tensor(15.4072, grad_fn=<AddBackward0>)
# 27 epoch_loss:tensor(0.4725, grad_fn=<AddBackward0>) total loss:tensor(15.8797, grad_fn=<AddBackward0>)
# 28 epoch_loss:tensor(0.4645, grad_fn=<AddBackward0>) total loss:tensor(16.3441, grad_fn=<AddBackward0>)
# 29 epoch_loss:tensor(0.4566, grad_fn=<AddBackward0>) total loss:tensor(16.8007, grad_fn=<AddBackward0>)
# 30 epoch_loss:tensor(0.4487, grad_fn=<AddBackward0>) total loss:tensor(17.2494, grad_fn=<AddBackward0>)
# 31 epoch_loss:tensor(0.4411, grad_fn=<AddBackward0>) total loss:tensor(17.6905, grad_fn=<AddBackward0>)
# 32 epoch_loss:tensor(0.4336, grad_fn=<AddBackward0>) total loss:tensor(18.1241, grad_fn=<AddBackward0>)
# 33 epoch_loss:tensor(0.4263, grad_fn=<AddBackward0>) total loss:tensor(18.5503, grad_fn=<AddBackward0>)
# 34 epoch_loss:tensor(0.4192, grad_fn=<AddBackward0>) total loss:tensor(18.9696, grad_fn=<AddBackward0>)
# 35 epoch_loss:tensor(0.4127, grad_fn=<AddBackward0>) total loss:tensor(19.3823, grad_fn=<AddBackward0>)
# 36 epoch_loss:tensor(0.4066, grad_fn=<AddBackward0>) total loss:tensor(19.7888, grad_fn=<AddBackward0>)
# 37 epoch_loss:tensor(0.4006, grad_fn=<AddBackward0>) total loss:tensor(20.1895, grad_fn=<AddBackward0>)
# 38 epoch_loss:tensor(0.3949, grad_fn=<AddBackward0>) total loss:tensor(20.5844, grad_fn=<AddBackward0>)
# 39 epoch_loss:tensor(0.3895, grad_fn=<AddBackward0>) total loss:tensor(20.9739, grad_fn=<AddBackward0>)
# 40 epoch_loss:tensor(0.3844, grad_fn=<AddBackward0>) total loss:tensor(21.3583, grad_fn=<AddBackward0>)
# 41 epoch_loss:tensor(0.3795, grad_fn=<AddBackward0>) total loss:tensor(21.7378, grad_fn=<AddBackward0>)
# 42 epoch_loss:tensor(0.3750, grad_fn=<AddBackward0>) total loss:tensor(22.1128, grad_fn=<AddBackward0>)
# 43 epoch_loss:tensor(0.3707, grad_fn=<AddBackward0>) total loss:tensor(22.4835, grad_fn=<AddBackward0>)
# 44 epoch_loss:tensor(0.3667, grad_fn=<AddBackward0>) total loss:tensor(22.8502, grad_fn=<AddBackward0>)
# 45 epoch_loss:tensor(0.3629, grad_fn=<AddBackward0>) total loss:tensor(23.2131, grad_fn=<AddBackward0>)
# 46 epoch_loss:tensor(0.3594, grad_fn=<AddBackward0>) total loss:tensor(23.5725, grad_fn=<AddBackward0>)
# 47 epoch_loss:tensor(0.3562, grad_fn=<AddBackward0>) total loss:tensor(23.9287, grad_fn=<AddBackward0>)
# 48 epoch_loss:tensor(0.3532, grad_fn=<AddBackward0>) total loss:tensor(24.2819, grad_fn=<AddBackward0>)
# 49 epoch_loss:tensor(0.3506, grad_fn=<AddBackward0>) total loss:tensor(24.6324, grad_fn=<AddBackward0>)
# 50 epoch_loss:tensor(0.3481, grad_fn=<AddBackward0>) total loss:tensor(24.9806, grad_fn=<AddBackward0>)
# 51 epoch_loss:tensor(0.3459, grad_fn=<AddBackward0>) total loss:tensor(25.3265, grad_fn=<AddBackward0>)
# 52 epoch_loss:tensor(0.3438, grad_fn=<AddBackward0>) total loss:tensor(25.6703, grad_fn=<AddBackward0>)
# 53 epoch_loss:tensor(0.3419, grad_fn=<AddBackward0>) total loss:tensor(26.0122, grad_fn=<AddBackward0>)
# 54 epoch_loss:tensor(0.3401, grad_fn=<AddBackward0>) total loss:tensor(26.3523, grad_fn=<AddBackward0>)
# 55 epoch_loss:tensor(0.3385, grad_fn=<AddBackward0>) total loss:tensor(26.6907, grad_fn=<AddBackward0>)
# 56 epoch_loss:tensor(0.3369, grad_fn=<AddBackward0>) total loss:tensor(27.0277, grad_fn=<AddBackward0>)
# 57 epoch_loss:tensor(0.3355, grad_fn=<AddBackward0>) total loss:tensor(27.3632, grad_fn=<AddBackward0>)
# 58 epoch_loss:tensor(0.3343, grad_fn=<AddBackward0>) total loss:tensor(27.6975, grad_fn=<AddBackward0>)
# 59 epoch_loss:tensor(0.3331, grad_fn=<AddBackward0>) total loss:tensor(28.0306, grad_fn=<AddBackward0>)
# 60 epoch_loss:tensor(0.3320, grad_fn=<AddBackward0>) total loss:tensor(28.3625, grad_fn=<AddBackward0>)
# 61 epoch_loss:tensor(0.3310, grad_fn=<AddBackward0>) total loss:tensor(28.6935, grad_fn=<AddBackward0>)
# 62 epoch_loss:tensor(0.3300, grad_fn=<AddBackward0>) total loss:tensor(29.0236, grad_fn=<AddBackward0>)
# 63 epoch_loss:tensor(0.3292, grad_fn=<AddBackward0>) total loss:tensor(29.3527, grad_fn=<AddBackward0>)
# 64 epoch_loss:tensor(0.3283, grad_fn=<AddBackward0>) total loss:tensor(29.6811, grad_fn=<AddBackward0>)
# 65 epoch_loss:tensor(0.3277, grad_fn=<AddBackward0>) total loss:tensor(30.0087, grad_fn=<AddBackward0>)
# 66 epoch_loss:tensor(0.3271, grad_fn=<AddBackward0>) total loss:tensor(30.3358, grad_fn=<AddBackward0>)
# 67 epoch_loss:tensor(0.3265, grad_fn=<AddBackward0>) total loss:tensor(30.6622, grad_fn=<AddBackward0>)
# 68 epoch_loss:tensor(0.3259, grad_fn=<AddBackward0>) total loss:tensor(30.9882, grad_fn=<AddBackward0>)
# 69 epoch_loss:tensor(0.3254, grad_fn=<AddBackward0>) total loss:tensor(31.3136, grad_fn=<AddBackward0>)
# 70 epoch_loss:tensor(0.3249, grad_fn=<AddBackward0>) total loss:tensor(31.6385, grad_fn=<AddBackward0>)
# 71 epoch_loss:tensor(0.3245, grad_fn=<AddBackward0>) total loss:tensor(31.9630, grad_fn=<AddBackward0>)
# 72 epoch_loss:tensor(0.3241, grad_fn=<AddBackward0>) total loss:tensor(32.2870, grad_fn=<AddBackward0>)
# 73 epoch_loss:tensor(0.3237, grad_fn=<AddBackward0>) total loss:tensor(32.6107, grad_fn=<AddBackward0>)
# 74 epoch_loss:tensor(0.3233, grad_fn=<AddBackward0>) total loss:tensor(32.9340, grad_fn=<AddBackward0>)
# 75 epoch_loss:tensor(0.3229, grad_fn=<AddBackward0>) total loss:tensor(33.2569, grad_fn=<AddBackward0>)
# 76 epoch_loss:tensor(0.3226, grad_fn=<AddBackward0>) total loss:tensor(33.5795, grad_fn=<AddBackward0>)
# 77 epoch_loss:tensor(0.3223, grad_fn=<AddBackward0>) total loss:tensor(33.9019, grad_fn=<AddBackward0>)
# 78 epoch_loss:tensor(0.3220, grad_fn=<AddBackward0>) total loss:tensor(34.2239, grad_fn=<AddBackward0>)
# 79 epoch_loss:tensor(0.3218, grad_fn=<AddBackward0>) total loss:tensor(34.5456, grad_fn=<AddBackward0>)
# 80 epoch_loss:tensor(0.3215, grad_fn=<AddBackward0>) total loss:tensor(34.8671, grad_fn=<AddBackward0>)
# 81 epoch_loss:tensor(0.3213, grad_fn=<AddBackward0>) total loss:tensor(35.1884, grad_fn=<AddBackward0>)
# 82 epoch_loss:tensor(0.3210, grad_fn=<AddBackward0>) total loss:tensor(35.5094, grad_fn=<AddBackward0>)
# 83 epoch_loss:tensor(0.3208, grad_fn=<AddBackward0>) total loss:tensor(35.8302, grad_fn=<AddBackward0>)
# 84 epoch_loss:tensor(0.3206, grad_fn=<AddBackward0>) total loss:tensor(36.1508, grad_fn=<AddBackward0>)
# 85 epoch_loss:tensor(0.3204, grad_fn=<AddBackward0>) total loss:tensor(36.4712, grad_fn=<AddBackward0>)
# 86 epoch_loss:tensor(0.3202, grad_fn=<AddBackward0>) total loss:tensor(36.7914, grad_fn=<AddBackward0>)
# 87 epoch_loss:tensor(0.3200, grad_fn=<AddBackward0>) total loss:tensor(37.1114, grad_fn=<AddBackward0>)
# 88 epoch_loss:tensor(0.3198, grad_fn=<AddBackward0>) total loss:tensor(37.4312, grad_fn=<AddBackward0>)
# 89 epoch_loss:tensor(0.3197, grad_fn=<AddBackward0>) total loss:tensor(37.7509, grad_fn=<AddBackward0>)
# 90 epoch_loss:tensor(0.3195, grad_fn=<AddBackward0>) total loss:tensor(38.0704, grad_fn=<AddBackward0>)
# 91 epoch_loss:tensor(0.3194, grad_fn=<AddBackward0>) total loss:tensor(38.3898, grad_fn=<AddBackward0>)
# 92 epoch_loss:tensor(0.3192, grad_fn=<AddBackward0>) total loss:tensor(38.7090, grad_fn=<AddBackward0>)
# 93 epoch_loss:tensor(0.3191, grad_fn=<AddBackward0>) total loss:tensor(39.0281, grad_fn=<AddBackward0>)
# 94 epoch_loss:tensor(0.3189, grad_fn=<AddBackward0>) total loss:tensor(39.3470, grad_fn=<AddBackward0>)
# 95 epoch_loss:tensor(0.3188, grad_fn=<AddBackward0>) total loss:tensor(39.6658, grad_fn=<AddBackward0>)
# 96 epoch_loss:tensor(0.3187, grad_fn=<AddBackward0>) total loss:tensor(39.9845, grad_fn=<AddBackward0>)
# 97 epoch_loss:tensor(0.3186, grad_fn=<AddBackward0>) total loss:tensor(40.3031, grad_fn=<AddBackward0>)
# 98 epoch_loss:tensor(0.3185, grad_fn=<AddBackward0>) total loss:tensor(40.6216, grad_fn=<AddBackward0>)
# 99 epoch_loss:tensor(0.3184, grad_fn=<AddBackward0>) total loss:tensor(40.9400, grad_fn=<AddBackward0>)
# 100 epoch_loss:tensor(0.3183, grad_fn=<AddBackward0>) total loss:tensor(41.2582, grad_fn=<AddBackward0>)
# 101 epoch_loss:tensor(0.3182, grad_fn=<AddBackward0>) total loss:tensor(41.5764, grad_fn=<AddBackward0>)
# 102 epoch_loss:tensor(0.3181, grad_fn=<AddBackward0>) total loss:tensor(41.8944, grad_fn=<AddBackward0>)
# 103 epoch_loss:tensor(0.3180, grad_fn=<AddBackward0>) total loss:tensor(42.2124, grad_fn=<AddBackward0>)
# 104 epoch_loss:tensor(0.3179, grad_fn=<AddBackward0>) total loss:tensor(42.5302, grad_fn=<AddBackward0>)
# 105 epoch_loss:tensor(0.3178, grad_fn=<AddBackward0>) total loss:tensor(42.8480, grad_fn=<AddBackward0>)
# 106 epoch_loss:tensor(0.3177, grad_fn=<AddBackward0>) total loss:tensor(43.1657, grad_fn=<AddBackward0>)
# 107 epoch_loss:tensor(0.3176, grad_fn=<AddBackward0>) total loss:tensor(43.4833, grad_fn=<AddBackward0>)
# 108 epoch_loss:tensor(0.3175, grad_fn=<AddBackward0>) total loss:tensor(43.8009, grad_fn=<AddBackward0>)
# 109 epoch_loss:tensor(0.3175, grad_fn=<AddBackward0>) total loss:tensor(44.1183, grad_fn=<AddBackward0>)
# 110 epoch_loss:tensor(0.3174, grad_fn=<AddBackward0>) total loss:tensor(44.4357, grad_fn=<AddBackward0>)
# 111 epoch_loss:tensor(0.3173, grad_fn=<AddBackward0>) total loss:tensor(44.7530, grad_fn=<AddBackward0>)
# 112 epoch_loss:tensor(0.3172, grad_fn=<AddBackward0>) total loss:tensor(45.0703, grad_fn=<AddBackward0>)
# 113 epoch_loss:tensor(0.3172, grad_fn=<AddBackward0>) total loss:tensor(45.3874, grad_fn=<AddBackward0>)
# 114 epoch_loss:tensor(0.3171, grad_fn=<AddBackward0>) total loss:tensor(45.7045, grad_fn=<AddBackward0>)
# 115 epoch_loss:tensor(0.3170, grad_fn=<AddBackward0>) total loss:tensor(46.0216, grad_fn=<AddBackward0>)
# 116 epoch_loss:tensor(0.3170, grad_fn=<AddBackward0>) total loss:tensor(46.3386, grad_fn=<AddBackward0>)
# 117 epoch_loss:tensor(0.3169, grad_fn=<AddBackward0>) total loss:tensor(46.6555, grad_fn=<AddBackward0>)
# 118 epoch_loss:tensor(0.3169, grad_fn=<AddBackward0>) total loss:tensor(46.9723, grad_fn=<AddBackward0>)
# 119 epoch_loss:tensor(0.3168, grad_fn=<AddBackward0>) total loss:tensor(47.2891, grad_fn=<AddBackward0>)
# 120 epoch_loss:tensor(0.3167, grad_fn=<AddBackward0>) total loss:tensor(47.6059, grad_fn=<AddBackward0>)
# 121 epoch_loss:tensor(0.3167, grad_fn=<AddBackward0>) total loss:tensor(47.9226, grad_fn=<AddBackward0>)
# 122 epoch_loss:tensor(0.3166, grad_fn=<AddBackward0>) total loss:tensor(48.2392, grad_fn=<AddBackward0>)
# 123 epoch_loss:tensor(0.3166, grad_fn=<AddBackward0>) total loss:tensor(48.5558, grad_fn=<AddBackward0>)
# 124 epoch_loss:tensor(0.3165, grad_fn=<AddBackward0>) total loss:tensor(48.8723, grad_fn=<AddBackward0>)
# 125 epoch_loss:tensor(0.3165, grad_fn=<AddBackward0>) total loss:tensor(49.1888, grad_fn=<AddBackward0>)
# 126 epoch_loss:tensor(0.3164, grad_fn=<AddBackward0>) total loss:tensor(49.5052, grad_fn=<AddBackward0>)
# 127 epoch_loss:tensor(0.3164, grad_fn=<AddBackward0>) total loss:tensor(49.8216, grad_fn=<AddBackward0>)
# 128 epoch_loss:tensor(0.3163, grad_fn=<AddBackward0>) total loss:tensor(50.1380, grad_fn=<AddBackward0>)
# 129 epoch_loss:tensor(0.3163, grad_fn=<AddBackward0>) total loss:tensor(50.4543, grad_fn=<AddBackward0>)
# 130 epoch_loss:tensor(0.3163, grad_fn=<AddBackward0>) total loss:tensor(50.7705, grad_fn=<AddBackward0>)
# 131 epoch_loss:tensor(0.3162, grad_fn=<AddBackward0>) total loss:tensor(51.0867, grad_fn=<AddBackward0>)
# 132 epoch_loss:tensor(0.3162, grad_fn=<AddBackward0>) total loss:tensor(51.4029, grad_fn=<AddBackward0>)
# 133 epoch_loss:tensor(0.3161, grad_fn=<AddBackward0>) total loss:tensor(51.7190, grad_fn=<AddBackward0>)
# 134 epoch_loss:tensor(0.3161, grad_fn=<AddBackward0>) total loss:tensor(52.0351, grad_fn=<AddBackward0>)
# 135 epoch_loss:tensor(0.3161, grad_fn=<AddBackward0>) total loss:tensor(52.3512, grad_fn=<AddBackward0>)
# 136 epoch_loss:tensor(0.3160, grad_fn=<AddBackward0>) total loss:tensor(52.6672, grad_fn=<AddBackward0>)
# 137 epoch_loss:tensor(0.3160, grad_fn=<AddBackward0>) total loss:tensor(52.9832, grad_fn=<AddBackward0>)
# 138 epoch_loss:tensor(0.3159, grad_fn=<AddBackward0>) total loss:tensor(53.2991, grad_fn=<AddBackward0>)
# 139 epoch_loss:tensor(0.3159, grad_fn=<AddBackward0>) total loss:tensor(53.6150, grad_fn=<AddBackward0>)
# 140 epoch_loss:tensor(0.3159, grad_fn=<AddBackward0>) total loss:tensor(53.9309, grad_fn=<AddBackward0>)
# 141 epoch_loss:tensor(0.3158, grad_fn=<AddBackward0>) total loss:tensor(54.2467, grad_fn=<AddBackward0>)
# 142 epoch_loss:tensor(0.3158, grad_fn=<AddBackward0>) total loss:tensor(54.5625, grad_fn=<AddBackward0>)
# 143 epoch_loss:tensor(0.3158, grad_fn=<AddBackward0>) total loss:tensor(54.8783, grad_fn=<AddBackward0>)
# 144 epoch_loss:tensor(0.3157, grad_fn=<AddBackward0>) total loss:tensor(55.1940, grad_fn=<AddBackward0>)
# 145 epoch_loss:tensor(0.3157, grad_fn=<AddBackward0>) total loss:tensor(55.5097, grad_fn=<AddBackward0>)
# 146 epoch_loss:tensor(0.3157, grad_fn=<AddBackward0>) total loss:tensor(55.8254, grad_fn=<AddBackward0>)
# 147 epoch_loss:tensor(0.3156, grad_fn=<AddBackward0>) total loss:tensor(56.1411, grad_fn=<AddBackward0>)
# 148 epoch_loss:tensor(0.3156, grad_fn=<AddBackward0>) total loss:tensor(56.4567, grad_fn=<AddBackward0>)
# 149 epoch_loss:tensor(0.3156, grad_fn=<AddBackward0>) total loss:tensor(56.7723, grad_fn=<AddBackward0>)
# 150 epoch_loss:tensor(0.3156, grad_fn=<AddBackward0>) total loss:tensor(57.0878, grad_fn=<AddBackward0>)
# 151 epoch_loss:tensor(0.3155, grad_fn=<AddBackward0>) total loss:tensor(57.4034, grad_fn=<AddBackward0>)
# 152 epoch_loss:tensor(0.3155, grad_fn=<AddBackward0>) total loss:tensor(57.7189, grad_fn=<AddBackward0>)
# 153 epoch_loss:tensor(0.3155, grad_fn=<AddBackward0>) total loss:tensor(58.0343, grad_fn=<AddBackward0>)
# 154 epoch_loss:tensor(0.3155, grad_fn=<AddBackward0>) total loss:tensor(58.3498, grad_fn=<AddBackward0>)
# 155 epoch_loss:tensor(0.3154, grad_fn=<AddBackward0>) total loss:tensor(58.6652, grad_fn=<AddBackward0>)
# 156 epoch_loss:tensor(0.3154, grad_fn=<AddBackward0>) total loss:tensor(58.9806, grad_fn=<AddBackward0>)
# 157 epoch_loss:tensor(0.3154, grad_fn=<AddBackward0>) total loss:tensor(59.2960, grad_fn=<AddBackward0>)
# 158 epoch_loss:tensor(0.3154, grad_fn=<AddBackward0>) total loss:tensor(59.6113, grad_fn=<AddBackward0>)
# 159 epoch_loss:tensor(0.3153, grad_fn=<AddBackward0>) total loss:tensor(59.9267, grad_fn=<AddBackward0>)
# 160 epoch_loss:tensor(0.3153, grad_fn=<AddBackward0>) total loss:tensor(60.2420, grad_fn=<AddBackward0>)
# 161 epoch_loss:tensor(0.3153, grad_fn=<AddBackward0>) total loss:tensor(60.5572, grad_fn=<AddBackward0>)
# 162 epoch_loss:tensor(0.3153, grad_fn=<AddBackward0>) total loss:tensor(60.8725, grad_fn=<AddBackward0>)
# 163 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(61.1877, grad_fn=<AddBackward0>)
# 164 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(61.5030, grad_fn=<AddBackward0>)
# 165 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(61.8181, grad_fn=<AddBackward0>)
# 166 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(62.1333, grad_fn=<AddBackward0>)
# 167 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(62.4485, grad_fn=<AddBackward0>)
# 168 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(62.7636, grad_fn=<AddBackward0>)
# 169 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(63.0787, grad_fn=<AddBackward0>)
# 170 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(63.3938, grad_fn=<AddBackward0>)
# 171 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(63.7089, grad_fn=<AddBackward0>)
# 172 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(64.0239, grad_fn=<AddBackward0>)
# 173 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(64.3390, grad_fn=<AddBackward0>)
# 174 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(64.6540, grad_fn=<AddBackward0>)
# 175 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(64.9690, grad_fn=<AddBackward0>)
# 176 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(65.2839, grad_fn=<AddBackward0>)
# 177 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(65.5989, grad_fn=<AddBackward0>)
# 178 epoch_loss:tensor(0.3149, grad_fn=<AddBackward0>) total loss:tensor(65.9138, grad_fn=<AddBackward0>)
# 179 epoch_loss:tensor(0.3149, grad_fn=<AddBackward0>) total loss:tensor(66.2288, grad_fn=<AddBackward0>)
# 180 epoch_loss:tensor(0.3149, grad_fn=<AddBackward0>) total loss:tensor(66.5437, grad_fn=<AddBackward0>)
# 181 epoch_loss:tensor(0.3149, grad_fn=<AddBackward0>) total loss:tensor(66.8586, grad_fn=<AddBackward0>)
# 182 epoch_loss:tensor(0.3149, grad_fn=<AddBackward0>) total loss:tensor(67.1734, grad_fn=<AddBackward0>)
# 183 epoch_loss:tensor(0.3149, grad_fn=<AddBackward0>) total loss:tensor(67.4883, grad_fn=<AddBackward0>)
# 184 epoch_loss:tensor(0.3148, grad_fn=<AddBackward0>) total loss:tensor(67.8031, grad_fn=<AddBackward0>)
# 185 epoch_loss:tensor(0.3148, grad_fn=<AddBackward0>) total loss:tensor(68.1180, grad_fn=<AddBackward0>)
# 186 epoch_loss:tensor(0.3148, grad_fn=<AddBackward0>) total loss:tensor(68.4328, grad_fn=<AddBackward0>)
# 187 epoch_loss:tensor(0.3148, grad_fn=<AddBackward0>) total loss:tensor(68.7476, grad_fn=<AddBackward0>)
# 188 epoch_loss:tensor(0.3148, grad_fn=<AddBackward0>) total loss:tensor(69.0624, grad_fn=<AddBackward0>)
# 189 epoch_loss:tensor(0.3148, grad_fn=<AddBackward0>) total loss:tensor(69.3771, grad_fn=<AddBackward0>)
# 190 epoch_loss:tensor(0.3148, grad_fn=<AddBackward0>) total loss:tensor(69.6919, grad_fn=<AddBackward0>)
# 191 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(70.0066, grad_fn=<AddBackward0>)
# 192 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(70.3214, grad_fn=<AddBackward0>)
# 193 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(70.6361, grad_fn=<AddBackward0>)
# 194 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(70.9508, grad_fn=<AddBackward0>)
# 195 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(71.2654, grad_fn=<AddBackward0>)
# 196 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(71.5801, grad_fn=<AddBackward0>)
# 197 epoch_loss:tensor(0.3147, grad_fn=<AddBackward0>) total loss:tensor(71.8948, grad_fn=<AddBackward0>)
# 198 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(72.2094, grad_fn=<AddBackward0>)
# 199 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(72.5241, grad_fn=<AddBackward0>)
# 200 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(72.8387, grad_fn=<AddBackward0>)
# 201 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(73.1533, grad_fn=<AddBackward0>)
# 202 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(73.4679, grad_fn=<AddBackward0>)
# 203 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(73.7825, grad_fn=<AddBackward0>)
# 204 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(74.0971, grad_fn=<AddBackward0>)
# 205 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(74.4116, grad_fn=<AddBackward0>)
# 206 epoch_loss:tensor(0.3146, grad_fn=<AddBackward0>) total loss:tensor(74.7262, grad_fn=<AddBackward0>)
# 207 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(75.0407, grad_fn=<AddBackward0>)
# 208 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(75.3553, grad_fn=<AddBackward0>)
# 209 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(75.6698, grad_fn=<AddBackward0>)
# 210 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(75.9843, grad_fn=<AddBackward0>)
# 211 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(76.2988, grad_fn=<AddBackward0>)
# 212 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(76.6133, grad_fn=<AddBackward0>)
# 213 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(76.9277, grad_fn=<AddBackward0>)
# 214 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(77.2422, grad_fn=<AddBackward0>)
# 215 epoch_loss:tensor(0.3145, grad_fn=<AddBackward0>) total loss:tensor(77.5567, grad_fn=<AddBackward0>)
# 216 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(77.8711, grad_fn=<AddBackward0>)
# 217 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(78.1856, grad_fn=<AddBackward0>)
# 218 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(78.5000, grad_fn=<AddBackward0>)
# 219 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(78.8144, grad_fn=<AddBackward0>)
# 220 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(79.1288, grad_fn=<AddBackward0>)
# 221 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(79.4432, grad_fn=<AddBackward0>)
# 222 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(79.7576, grad_fn=<AddBackward0>)
# 223 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(80.0720, grad_fn=<AddBackward0>)
# 224 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(80.3864, grad_fn=<AddBackward0>)
# 225 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(80.7007, grad_fn=<AddBackward0>)
# 226 epoch_loss:tensor(0.3144, grad_fn=<AddBackward0>) total loss:tensor(81.0151, grad_fn=<AddBackward0>)
# 227 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(81.3294, grad_fn=<AddBackward0>)
# 228 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(81.6438, grad_fn=<AddBackward0>)
# 229 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(81.9581, grad_fn=<AddBackward0>)
# 230 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(82.2724, grad_fn=<AddBackward0>)
# 231 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(82.5867, grad_fn=<AddBackward0>)
# 232 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(82.9010, grad_fn=<AddBackward0>)
# 233 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(83.2153, grad_fn=<AddBackward0>)
# 234 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(83.5296, grad_fn=<AddBackward0>)
# 235 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(83.8439, grad_fn=<AddBackward0>)
# 236 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(84.1581, grad_fn=<AddBackward0>)
# 237 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(84.4724, grad_fn=<AddBackward0>)
# 238 epoch_loss:tensor(0.3143, grad_fn=<AddBackward0>) total loss:tensor(84.7867, grad_fn=<AddBackward0>)
# 239 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(85.1009, grad_fn=<AddBackward0>)
# 240 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(85.4152, grad_fn=<AddBackward0>)
# 241 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(85.7294, grad_fn=<AddBackward0>)
# 242 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(86.0436, grad_fn=<AddBackward0>)
# 243 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(86.3578, grad_fn=<AddBackward0>)
# 244 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(86.6721, grad_fn=<AddBackward0>)
# 245 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(86.9863, grad_fn=<AddBackward0>)
# 246 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(87.3005, grad_fn=<AddBackward0>)
# 247 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(87.6147, grad_fn=<AddBackward0>)
# 248 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(87.9288, grad_fn=<AddBackward0>)
# 249 epoch_loss:tensor(0.3142, grad_fn=<AddBackward0>) total loss:tensor(88.2430, grad_fn=<AddBackward0>)
# validation loss is equal to: tensor(0.5126, grad_fn=<NllLossBackward0>)
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        16
#            1       0.94      0.94      0.94        16
#
#     accuracy                           0.94        32
#    macro avg       0.94      0.94      0.94        32
# weighted avg       0.94      0.94      0.94        32

# %% [markdown]
# ### Kiểm thử với embedding sinh ra bởi random walk.

# %%
model=GCN(inputs_shape=ne_dw.shape[1],outputs_shape=4,n_classes=2)

trainer = Trainer(
    model,
    optimizer = optim.Adam(model.parameters(), lr=0.01),
    loss_function=F.cross_entropy,
    epochs=250,
    adj_matrix=adj_matrix,
    input_features=ne_dw
)

trainer.train(X_train,Y_train)
trainer.test(X_test,Y_test)
trainer.visualize_classification(graph,Y_test,classification=True)
# Out:
# /root/anaconda3/envs/mlgcn/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 0 epoch_loss:tensor(0.7044, grad_fn=<AddBackward0>) total loss:tensor(0.7044, grad_fn=<AddBackward0>)
# 1 epoch_loss:tensor(0.6863, grad_fn=<AddBackward0>) total loss:tensor(1.3906, grad_fn=<AddBackward0>)
# 2 epoch_loss:tensor(0.6689, grad_fn=<AddBackward0>) total loss:tensor(2.0595, grad_fn=<AddBackward0>)
# 3 epoch_loss:tensor(0.6521, grad_fn=<AddBackward0>) total loss:tensor(2.7116, grad_fn=<AddBackward0>)
# 4 epoch_loss:tensor(0.6358, grad_fn=<AddBackward0>) total loss:tensor(3.3473, grad_fn=<AddBackward0>)
# 5 epoch_loss:tensor(0.6199, grad_fn=<AddBackward0>) total loss:tensor(3.9673, grad_fn=<AddBackward0>)
# 6 epoch_loss:tensor(0.6044, grad_fn=<AddBackward0>) total loss:tensor(4.5716, grad_fn=<AddBackward0>)
# 7 epoch_loss:tensor(0.5891, grad_fn=<AddBackward0>) total loss:tensor(5.1607, grad_fn=<AddBackward0>)
# 8 epoch_loss:tensor(0.5740, grad_fn=<AddBackward0>) total loss:tensor(5.7347, grad_fn=<AddBackward0>)
# 9 epoch_loss:tensor(0.5591, grad_fn=<AddBackward0>) total loss:tensor(6.2938, grad_fn=<AddBackward0>)
# 10 epoch_loss:tensor(0.5444, grad_fn=<AddBackward0>) total loss:tensor(6.8382, grad_fn=<AddBackward0>)
# 11 epoch_loss:tensor(0.5298, grad_fn=<AddBackward0>) total loss:tensor(7.3680, grad_fn=<AddBackward0>)
# 12 epoch_loss:tensor(0.5171, grad_fn=<AddBackward0>) total loss:tensor(7.8851, grad_fn=<AddBackward0>)
# 13 epoch_loss:tensor(0.5053, grad_fn=<AddBackward0>) total loss:tensor(8.3904, grad_fn=<AddBackward0>)
# 14 epoch_loss:tensor(0.4937, grad_fn=<AddBackward0>) total loss:tensor(8.8841, grad_fn=<AddBackward0>)
# 15 epoch_loss:tensor(0.4827, grad_fn=<AddBackward0>) total loss:tensor(9.3668, grad_fn=<AddBackward0>)
# 16 epoch_loss:tensor(0.4728, grad_fn=<AddBackward0>) total loss:tensor(9.8396, grad_fn=<AddBackward0>)
# 17 epoch_loss:tensor(0.4631, grad_fn=<AddBackward0>) total loss:tensor(10.3027, grad_fn=<AddBackward0>)
# 18 epoch_loss:tensor(0.4545, grad_fn=<AddBackward0>) total loss:tensor(10.7572, grad_fn=<AddBackward0>)
# 19 epoch_loss:tensor(0.4475, grad_fn=<AddBackward0>) total loss:tensor(11.2048, grad_fn=<AddBackward0>)
# 20 epoch_loss:tensor(0.4409, grad_fn=<AddBackward0>) total loss:tensor(11.6457, grad_fn=<AddBackward0>)
# 21 epoch_loss:tensor(0.4345, grad_fn=<AddBackward0>) total loss:tensor(12.0801, grad_fn=<AddBackward0>)
# 22 epoch_loss:tensor(0.4285, grad_fn=<AddBackward0>) total loss:tensor(12.5087, grad_fn=<AddBackward0>)
# 23 epoch_loss:tensor(0.4240, grad_fn=<AddBackward0>) total loss:tensor(12.9327, grad_fn=<AddBackward0>)
# 24 epoch_loss:tensor(0.4205, grad_fn=<AddBackward0>) total loss:tensor(13.3532, grad_fn=<AddBackward0>)
# 25 epoch_loss:tensor(0.4171, grad_fn=<AddBackward0>) total loss:tensor(13.7704, grad_fn=<AddBackward0>)
# 26 epoch_loss:tensor(0.4142, grad_fn=<AddBackward0>) total loss:tensor(14.1846, grad_fn=<AddBackward0>)
# 27 epoch_loss:tensor(0.4117, grad_fn=<AddBackward0>) total loss:tensor(14.5963, grad_fn=<AddBackward0>)
# 28 epoch_loss:tensor(0.4097, grad_fn=<AddBackward0>) total loss:tensor(15.0060, grad_fn=<AddBackward0>)
# 29 epoch_loss:tensor(0.4078, grad_fn=<AddBackward0>) total loss:tensor(15.4138, grad_fn=<AddBackward0>)
# 30 epoch_loss:tensor(0.4057, grad_fn=<AddBackward0>) total loss:tensor(15.8195, grad_fn=<AddBackward0>)
# 31 epoch_loss:tensor(0.4037, grad_fn=<AddBackward0>) total loss:tensor(16.2232, grad_fn=<AddBackward0>)
# 32 epoch_loss:tensor(0.4017, grad_fn=<AddBackward0>) total loss:tensor(16.6249, grad_fn=<AddBackward0>)
# 33 epoch_loss:tensor(0.4000, grad_fn=<AddBackward0>) total loss:tensor(17.0249, grad_fn=<AddBackward0>)
# 34 epoch_loss:tensor(0.3984, grad_fn=<AddBackward0>) total loss:tensor(17.4233, grad_fn=<AddBackward0>)
# 35 epoch_loss:tensor(0.3968, grad_fn=<AddBackward0>) total loss:tensor(17.8202, grad_fn=<AddBackward0>)
# 36 epoch_loss:tensor(0.3953, grad_fn=<AddBackward0>) total loss:tensor(18.2154, grad_fn=<AddBackward0>)
# 37 epoch_loss:tensor(0.3938, grad_fn=<AddBackward0>) total loss:tensor(18.6092, grad_fn=<AddBackward0>)
# 38 epoch_loss:tensor(0.3923, grad_fn=<AddBackward0>) total loss:tensor(19.0015, grad_fn=<AddBackward0>)
# 39 epoch_loss:tensor(0.3909, grad_fn=<AddBackward0>) total loss:tensor(19.3924, grad_fn=<AddBackward0>)
# 40 epoch_loss:tensor(0.3895, grad_fn=<AddBackward0>) total loss:tensor(19.7820, grad_fn=<AddBackward0>)
# 41 epoch_loss:tensor(0.3882, grad_fn=<AddBackward0>) total loss:tensor(20.1701, grad_fn=<AddBackward0>)
# 42 epoch_loss:tensor(0.3869, grad_fn=<AddBackward0>) total loss:tensor(20.5570, grad_fn=<AddBackward0>)
# 43 epoch_loss:tensor(0.3856, grad_fn=<AddBackward0>) total loss:tensor(20.9426, grad_fn=<AddBackward0>)
# 44 epoch_loss:tensor(0.3843, grad_fn=<AddBackward0>) total loss:tensor(21.3270, grad_fn=<AddBackward0>)
# 45 epoch_loss:tensor(0.3831, grad_fn=<AddBackward0>) total loss:tensor(21.7101, grad_fn=<AddBackward0>)
# 46 epoch_loss:tensor(0.3819, grad_fn=<AddBackward0>) total loss:tensor(22.0920, grad_fn=<AddBackward0>)
# 47 epoch_loss:tensor(0.3808, grad_fn=<AddBackward0>) total loss:tensor(22.4728, grad_fn=<AddBackward0>)
# 48 epoch_loss:tensor(0.3797, grad_fn=<AddBackward0>) total loss:tensor(22.8525, grad_fn=<AddBackward0>)
# 49 epoch_loss:tensor(0.3786, grad_fn=<AddBackward0>) total loss:tensor(23.2310, grad_fn=<AddBackward0>)
# 50 epoch_loss:tensor(0.3775, grad_fn=<AddBackward0>) total loss:tensor(23.6085, grad_fn=<AddBackward0>)
# 51 epoch_loss:tensor(0.3764, grad_fn=<AddBackward0>) total loss:tensor(23.9849, grad_fn=<AddBackward0>)
# 52 epoch_loss:tensor(0.3754, grad_fn=<AddBackward0>) total loss:tensor(24.3603, grad_fn=<AddBackward0>)
# 53 epoch_loss:tensor(0.3744, grad_fn=<AddBackward0>) total loss:tensor(24.7347, grad_fn=<AddBackward0>)
# 54 epoch_loss:tensor(0.3734, grad_fn=<AddBackward0>) total loss:tensor(25.1081, grad_fn=<AddBackward0>)
# 55 epoch_loss:tensor(0.3725, grad_fn=<AddBackward0>) total loss:tensor(25.4806, grad_fn=<AddBackward0>)
# 56 epoch_loss:tensor(0.3715, grad_fn=<AddBackward0>) total loss:tensor(25.8521, grad_fn=<AddBackward0>)
# 57 epoch_loss:tensor(0.3706, grad_fn=<AddBackward0>) total loss:tensor(26.2227, grad_fn=<AddBackward0>)
# 58 epoch_loss:tensor(0.3697, grad_fn=<AddBackward0>) total loss:tensor(26.5925, grad_fn=<AddBackward0>)
# 59 epoch_loss:tensor(0.3689, grad_fn=<AddBackward0>) total loss:tensor(26.9613, grad_fn=<AddBackward0>)
# 60 epoch_loss:tensor(0.3680, grad_fn=<AddBackward0>) total loss:tensor(27.3293, grad_fn=<AddBackward0>)
# 61 epoch_loss:tensor(0.3672, grad_fn=<AddBackward0>) total loss:tensor(27.6965, grad_fn=<AddBackward0>)
# 62 epoch_loss:tensor(0.3664, grad_fn=<AddBackward0>) total loss:tensor(28.0629, grad_fn=<AddBackward0>)
# 63 epoch_loss:tensor(0.3656, grad_fn=<AddBackward0>) total loss:tensor(28.4285, grad_fn=<AddBackward0>)
# 64 epoch_loss:tensor(0.3648, grad_fn=<AddBackward0>) total loss:tensor(28.7933, grad_fn=<AddBackward0>)
# 65 epoch_loss:tensor(0.3640, grad_fn=<AddBackward0>) total loss:tensor(29.1573, grad_fn=<AddBackward0>)
# 66 epoch_loss:tensor(0.3633, grad_fn=<AddBackward0>) total loss:tensor(29.5206, grad_fn=<AddBackward0>)
# 67 epoch_loss:tensor(0.3626, grad_fn=<AddBackward0>) total loss:tensor(29.8832, grad_fn=<AddBackward0>)
# 68 epoch_loss:tensor(0.3619, grad_fn=<AddBackward0>) total loss:tensor(30.2451, grad_fn=<AddBackward0>)
# 69 epoch_loss:tensor(0.3612, grad_fn=<AddBackward0>) total loss:tensor(30.6063, grad_fn=<AddBackward0>)
# 70 epoch_loss:tensor(0.3605, grad_fn=<AddBackward0>) total loss:tensor(30.9668, grad_fn=<AddBackward0>)
# 71 epoch_loss:tensor(0.3599, grad_fn=<AddBackward0>) total loss:tensor(31.3266, grad_fn=<AddBackward0>)
# 72 epoch_loss:tensor(0.3592, grad_fn=<AddBackward0>) total loss:tensor(31.6858, grad_fn=<AddBackward0>)
# 73 epoch_loss:tensor(0.3586, grad_fn=<AddBackward0>) total loss:tensor(32.0444, grad_fn=<AddBackward0>)
# 74 epoch_loss:tensor(0.3580, grad_fn=<AddBackward0>) total loss:tensor(32.4024, grad_fn=<AddBackward0>)
# 75 epoch_loss:tensor(0.3574, grad_fn=<AddBackward0>) total loss:tensor(32.7597, grad_fn=<AddBackward0>)
# 76 epoch_loss:tensor(0.3568, grad_fn=<AddBackward0>) total loss:tensor(33.1165, grad_fn=<AddBackward0>)
# 77 epoch_loss:tensor(0.3562, grad_fn=<AddBackward0>) total loss:tensor(33.4727, grad_fn=<AddBackward0>)
# 78 epoch_loss:tensor(0.3556, grad_fn=<AddBackward0>) total loss:tensor(33.8283, grad_fn=<AddBackward0>)
# 79 epoch_loss:tensor(0.3551, grad_fn=<AddBackward0>) total loss:tensor(34.1834, grad_fn=<AddBackward0>)
# 80 epoch_loss:tensor(0.3545, grad_fn=<AddBackward0>) total loss:tensor(34.5379, grad_fn=<AddBackward0>)
# 81 epoch_loss:tensor(0.3540, grad_fn=<AddBackward0>) total loss:tensor(34.8919, grad_fn=<AddBackward0>)
# 82 epoch_loss:tensor(0.3535, grad_fn=<AddBackward0>) total loss:tensor(35.2453, grad_fn=<AddBackward0>)
# 83 epoch_loss:tensor(0.3530, grad_fn=<AddBackward0>) total loss:tensor(35.5983, grad_fn=<AddBackward0>)
# 84 epoch_loss:tensor(0.3525, grad_fn=<AddBackward0>) total loss:tensor(35.9508, grad_fn=<AddBackward0>)
# 85 epoch_loss:tensor(0.3520, grad_fn=<AddBackward0>) total loss:tensor(36.3027, grad_fn=<AddBackward0>)
# 86 epoch_loss:tensor(0.3515, grad_fn=<AddBackward0>) total loss:tensor(36.6542, grad_fn=<AddBackward0>)
# 87 epoch_loss:tensor(0.3510, grad_fn=<AddBackward0>) total loss:tensor(37.0052, grad_fn=<AddBackward0>)
# 88 epoch_loss:tensor(0.3506, grad_fn=<AddBackward0>) total loss:tensor(37.3558, grad_fn=<AddBackward0>)
# 89 epoch_loss:tensor(0.3501, grad_fn=<AddBackward0>) total loss:tensor(37.7059, grad_fn=<AddBackward0>)
# 90 epoch_loss:tensor(0.3497, grad_fn=<AddBackward0>) total loss:tensor(38.0556, grad_fn=<AddBackward0>)
# 91 epoch_loss:tensor(0.3492, grad_fn=<AddBackward0>) total loss:tensor(38.4048, grad_fn=<AddBackward0>)
# 92 epoch_loss:tensor(0.3488, grad_fn=<AddBackward0>) total loss:tensor(38.7536, grad_fn=<AddBackward0>)
# 93 epoch_loss:tensor(0.3484, grad_fn=<AddBackward0>) total loss:tensor(39.1020, grad_fn=<AddBackward0>)
# 94 epoch_loss:tensor(0.3480, grad_fn=<AddBackward0>) total loss:tensor(39.4499, grad_fn=<AddBackward0>)
# 95 epoch_loss:tensor(0.3476, grad_fn=<AddBackward0>) total loss:tensor(39.7975, grad_fn=<AddBackward0>)
# 96 epoch_loss:tensor(0.3472, grad_fn=<AddBackward0>) total loss:tensor(40.1447, grad_fn=<AddBackward0>)
# 97 epoch_loss:tensor(0.3468, grad_fn=<AddBackward0>) total loss:tensor(40.4914, grad_fn=<AddBackward0>)
# 98 epoch_loss:tensor(0.3464, grad_fn=<AddBackward0>) total loss:tensor(40.8378, grad_fn=<AddBackward0>)
# 99 epoch_loss:tensor(0.3460, grad_fn=<AddBackward0>) total loss:tensor(41.1839, grad_fn=<AddBackward0>)
# 100 epoch_loss:tensor(0.3457, grad_fn=<AddBackward0>) total loss:tensor(41.5295, grad_fn=<AddBackward0>)
# 101 epoch_loss:tensor(0.3453, grad_fn=<AddBackward0>) total loss:tensor(41.8748, grad_fn=<AddBackward0>)
# 102 epoch_loss:tensor(0.3449, grad_fn=<AddBackward0>) total loss:tensor(42.2198, grad_fn=<AddBackward0>)
# 103 epoch_loss:tensor(0.3446, grad_fn=<AddBackward0>) total loss:tensor(42.5644, grad_fn=<AddBackward0>)
# 104 epoch_loss:tensor(0.3443, grad_fn=<AddBackward0>) total loss:tensor(42.9086, grad_fn=<AddBackward0>)
# 105 epoch_loss:tensor(0.3439, grad_fn=<AddBackward0>) total loss:tensor(43.2526, grad_fn=<AddBackward0>)
# 106 epoch_loss:tensor(0.3436, grad_fn=<AddBackward0>) total loss:tensor(43.5962, grad_fn=<AddBackward0>)
# 107 epoch_loss:tensor(0.3433, grad_fn=<AddBackward0>) total loss:tensor(43.9394, grad_fn=<AddBackward0>)
# 108 epoch_loss:tensor(0.3430, grad_fn=<AddBackward0>) total loss:tensor(44.2824, grad_fn=<AddBackward0>)
# 109 epoch_loss:tensor(0.3426, grad_fn=<AddBackward0>) total loss:tensor(44.6250, grad_fn=<AddBackward0>)
# 110 epoch_loss:tensor(0.3423, grad_fn=<AddBackward0>) total loss:tensor(44.9674, grad_fn=<AddBackward0>)
# 111 epoch_loss:tensor(0.3420, grad_fn=<AddBackward0>) total loss:tensor(45.3094, grad_fn=<AddBackward0>)
# 112 epoch_loss:tensor(0.3417, grad_fn=<AddBackward0>) total loss:tensor(45.6511, grad_fn=<AddBackward0>)
# 113 epoch_loss:tensor(0.3414, grad_fn=<AddBackward0>) total loss:tensor(45.9926, grad_fn=<AddBackward0>)
# 114 epoch_loss:tensor(0.3412, grad_fn=<AddBackward0>) total loss:tensor(46.3337, grad_fn=<AddBackward0>)
# 115 epoch_loss:tensor(0.3409, grad_fn=<AddBackward0>) total loss:tensor(46.6746, grad_fn=<AddBackward0>)
# 116 epoch_loss:tensor(0.3406, grad_fn=<AddBackward0>) total loss:tensor(47.0152, grad_fn=<AddBackward0>)
# 117 epoch_loss:tensor(0.3403, grad_fn=<AddBackward0>) total loss:tensor(47.3555, grad_fn=<AddBackward0>)
# 118 epoch_loss:tensor(0.3401, grad_fn=<AddBackward0>) total loss:tensor(47.6956, grad_fn=<AddBackward0>)
# 119 epoch_loss:tensor(0.3398, grad_fn=<AddBackward0>) total loss:tensor(48.0354, grad_fn=<AddBackward0>)
# 120 epoch_loss:tensor(0.3395, grad_fn=<AddBackward0>) total loss:tensor(48.3749, grad_fn=<AddBackward0>)
# 121 epoch_loss:tensor(0.3393, grad_fn=<AddBackward0>) total loss:tensor(48.7142, grad_fn=<AddBackward0>)
# 122 epoch_loss:tensor(0.3390, grad_fn=<AddBackward0>) total loss:tensor(49.0532, grad_fn=<AddBackward0>)
# 123 epoch_loss:tensor(0.3388, grad_fn=<AddBackward0>) total loss:tensor(49.3920, grad_fn=<AddBackward0>)
# 124 epoch_loss:tensor(0.3385, grad_fn=<AddBackward0>) total loss:tensor(49.7305, grad_fn=<AddBackward0>)
# 125 epoch_loss:tensor(0.3383, grad_fn=<AddBackward0>) total loss:tensor(50.0688, grad_fn=<AddBackward0>)
# 126 epoch_loss:tensor(0.3381, grad_fn=<AddBackward0>) total loss:tensor(50.4069, grad_fn=<AddBackward0>)
# 127 epoch_loss:tensor(0.3378, grad_fn=<AddBackward0>) total loss:tensor(50.7447, grad_fn=<AddBackward0>)
# 128 epoch_loss:tensor(0.3376, grad_fn=<AddBackward0>) total loss:tensor(51.0823, grad_fn=<AddBackward0>)
# 129 epoch_loss:tensor(0.3374, grad_fn=<AddBackward0>) total loss:tensor(51.4197, grad_fn=<AddBackward0>)
# 130 epoch_loss:tensor(0.3371, grad_fn=<AddBackward0>) total loss:tensor(51.7568, grad_fn=<AddBackward0>)
# 131 epoch_loss:tensor(0.3369, grad_fn=<AddBackward0>) total loss:tensor(52.0938, grad_fn=<AddBackward0>)
# 132 epoch_loss:tensor(0.3367, grad_fn=<AddBackward0>) total loss:tensor(52.4305, grad_fn=<AddBackward0>)
# 133 epoch_loss:tensor(0.3365, grad_fn=<AddBackward0>) total loss:tensor(52.7670, grad_fn=<AddBackward0>)
# 134 epoch_loss:tensor(0.3363, grad_fn=<AddBackward0>) total loss:tensor(53.1033, grad_fn=<AddBackward0>)
# 135 epoch_loss:tensor(0.3361, grad_fn=<AddBackward0>) total loss:tensor(53.4394, grad_fn=<AddBackward0>)
# 136 epoch_loss:tensor(0.3359, grad_fn=<AddBackward0>) total loss:tensor(53.7753, grad_fn=<AddBackward0>)
# 137 epoch_loss:tensor(0.3357, grad_fn=<AddBackward0>) total loss:tensor(54.1110, grad_fn=<AddBackward0>)
# 138 epoch_loss:tensor(0.3355, grad_fn=<AddBackward0>) total loss:tensor(54.4464, grad_fn=<AddBackward0>)
# 139 epoch_loss:tensor(0.3353, grad_fn=<AddBackward0>) total loss:tensor(54.7817, grad_fn=<AddBackward0>)
# 140 epoch_loss:tensor(0.3351, grad_fn=<AddBackward0>) total loss:tensor(55.1168, grad_fn=<AddBackward0>)
# 141 epoch_loss:tensor(0.3349, grad_fn=<AddBackward0>) total loss:tensor(55.4517, grad_fn=<AddBackward0>)
# 142 epoch_loss:tensor(0.3347, grad_fn=<AddBackward0>) total loss:tensor(55.7865, grad_fn=<AddBackward0>)
# 143 epoch_loss:tensor(0.3345, grad_fn=<AddBackward0>) total loss:tensor(56.1210, grad_fn=<AddBackward0>)
# 144 epoch_loss:tensor(0.3344, grad_fn=<AddBackward0>) total loss:tensor(56.4554, grad_fn=<AddBackward0>)
# 145 epoch_loss:tensor(0.3342, grad_fn=<AddBackward0>) total loss:tensor(56.7896, grad_fn=<AddBackward0>)
# 146 epoch_loss:tensor(0.3340, grad_fn=<AddBackward0>) total loss:tensor(57.1236, grad_fn=<AddBackward0>)
# 147 epoch_loss:tensor(0.3338, grad_fn=<AddBackward0>) total loss:tensor(57.4574, grad_fn=<AddBackward0>)
# 148 epoch_loss:tensor(0.3337, grad_fn=<AddBackward0>) total loss:tensor(57.7911, grad_fn=<AddBackward0>)
# 149 epoch_loss:tensor(0.3335, grad_fn=<AddBackward0>) total loss:tensor(58.1245, grad_fn=<AddBackward0>)
# 150 epoch_loss:tensor(0.3333, grad_fn=<AddBackward0>) total loss:tensor(58.4579, grad_fn=<AddBackward0>)
# 151 epoch_loss:tensor(0.3332, grad_fn=<AddBackward0>) total loss:tensor(58.7910, grad_fn=<AddBackward0>)
# 152 epoch_loss:tensor(0.3330, grad_fn=<AddBackward0>) total loss:tensor(59.1240, grad_fn=<AddBackward0>)
# 153 epoch_loss:tensor(0.3328, grad_fn=<AddBackward0>) total loss:tensor(59.4569, grad_fn=<AddBackward0>)
# 154 epoch_loss:tensor(0.3327, grad_fn=<AddBackward0>) total loss:tensor(59.7896, grad_fn=<AddBackward0>)
# 155 epoch_loss:tensor(0.3325, grad_fn=<AddBackward0>) total loss:tensor(60.1221, grad_fn=<AddBackward0>)
# 156 epoch_loss:tensor(0.3324, grad_fn=<AddBackward0>) total loss:tensor(60.4544, grad_fn=<AddBackward0>)
# 157 epoch_loss:tensor(0.3322, grad_fn=<AddBackward0>) total loss:tensor(60.7867, grad_fn=<AddBackward0>)
# 158 epoch_loss:tensor(0.3321, grad_fn=<AddBackward0>) total loss:tensor(61.1187, grad_fn=<AddBackward0>)
# 159 epoch_loss:tensor(0.3319, grad_fn=<AddBackward0>) total loss:tensor(61.4506, grad_fn=<AddBackward0>)
# 160 epoch_loss:tensor(0.3318, grad_fn=<AddBackward0>) total loss:tensor(61.7824, grad_fn=<AddBackward0>)
# 161 epoch_loss:tensor(0.3316, grad_fn=<AddBackward0>) total loss:tensor(62.1140, grad_fn=<AddBackward0>)
# 162 epoch_loss:tensor(0.3315, grad_fn=<AddBackward0>) total loss:tensor(62.4455, grad_fn=<AddBackward0>)
# 163 epoch_loss:tensor(0.3313, grad_fn=<AddBackward0>) total loss:tensor(62.7769, grad_fn=<AddBackward0>)
# 164 epoch_loss:tensor(0.3312, grad_fn=<AddBackward0>) total loss:tensor(63.1081, grad_fn=<AddBackward0>)
# 165 epoch_loss:tensor(0.3311, grad_fn=<AddBackward0>) total loss:tensor(63.4392, grad_fn=<AddBackward0>)
# 166 epoch_loss:tensor(0.3309, grad_fn=<AddBackward0>) total loss:tensor(63.7701, grad_fn=<AddBackward0>)
# 167 epoch_loss:tensor(0.3308, grad_fn=<AddBackward0>) total loss:tensor(64.1009, grad_fn=<AddBackward0>)
# 168 epoch_loss:tensor(0.3307, grad_fn=<AddBackward0>) total loss:tensor(64.4316, grad_fn=<AddBackward0>)
# 169 epoch_loss:tensor(0.3305, grad_fn=<AddBackward0>) total loss:tensor(64.7621, grad_fn=<AddBackward0>)
# 170 epoch_loss:tensor(0.3304, grad_fn=<AddBackward0>) total loss:tensor(65.0925, grad_fn=<AddBackward0>)
# 171 epoch_loss:tensor(0.3303, grad_fn=<AddBackward0>) total loss:tensor(65.4228, grad_fn=<AddBackward0>)
# 172 epoch_loss:tensor(0.3302, grad_fn=<AddBackward0>) total loss:tensor(65.7529, grad_fn=<AddBackward0>)
# 173 epoch_loss:tensor(0.3300, grad_fn=<AddBackward0>) total loss:tensor(66.0830, grad_fn=<AddBackward0>)
# 174 epoch_loss:tensor(0.3299, grad_fn=<AddBackward0>) total loss:tensor(66.4129, grad_fn=<AddBackward0>)
# 175 epoch_loss:tensor(0.3298, grad_fn=<AddBackward0>) total loss:tensor(66.7426, grad_fn=<AddBackward0>)
# 176 epoch_loss:tensor(0.3297, grad_fn=<AddBackward0>) total loss:tensor(67.0723, grad_fn=<AddBackward0>)
# 177 epoch_loss:tensor(0.3295, grad_fn=<AddBackward0>) total loss:tensor(67.4019, grad_fn=<AddBackward0>)
# 178 epoch_loss:tensor(0.3294, grad_fn=<AddBackward0>) total loss:tensor(67.7313, grad_fn=<AddBackward0>)
# 179 epoch_loss:tensor(0.3293, grad_fn=<AddBackward0>) total loss:tensor(68.0606, grad_fn=<AddBackward0>)
# 180 epoch_loss:tensor(0.3292, grad_fn=<AddBackward0>) total loss:tensor(68.3898, grad_fn=<AddBackward0>)
# 181 epoch_loss:tensor(0.3291, grad_fn=<AddBackward0>) total loss:tensor(68.7189, grad_fn=<AddBackward0>)
# 182 epoch_loss:tensor(0.3290, grad_fn=<AddBackward0>) total loss:tensor(69.0478, grad_fn=<AddBackward0>)
# 183 epoch_loss:tensor(0.3289, grad_fn=<AddBackward0>) total loss:tensor(69.3767, grad_fn=<AddBackward0>)
# 184 epoch_loss:tensor(0.3288, grad_fn=<AddBackward0>) total loss:tensor(69.7055, grad_fn=<AddBackward0>)
# 185 epoch_loss:tensor(0.3286, grad_fn=<AddBackward0>) total loss:tensor(70.0341, grad_fn=<AddBackward0>)
# 186 epoch_loss:tensor(0.3285, grad_fn=<AddBackward0>) total loss:tensor(70.3626, grad_fn=<AddBackward0>)
# 187 epoch_loss:tensor(0.3284, grad_fn=<AddBackward0>) total loss:tensor(70.6911, grad_fn=<AddBackward0>)
# 188 epoch_loss:tensor(0.3283, grad_fn=<AddBackward0>) total loss:tensor(71.0194, grad_fn=<AddBackward0>)
# 189 epoch_loss:tensor(0.3282, grad_fn=<AddBackward0>) total loss:tensor(71.3476, grad_fn=<AddBackward0>)
# 190 epoch_loss:tensor(0.3281, grad_fn=<AddBackward0>) total loss:tensor(71.6758, grad_fn=<AddBackward0>)
# 191 epoch_loss:tensor(0.3280, grad_fn=<AddBackward0>) total loss:tensor(72.0038, grad_fn=<AddBackward0>)
# 192 epoch_loss:tensor(0.3279, grad_fn=<AddBackward0>) total loss:tensor(72.3317, grad_fn=<AddBackward0>)
# 193 epoch_loss:tensor(0.3278, grad_fn=<AddBackward0>) total loss:tensor(72.6595, grad_fn=<AddBackward0>)
# 194 epoch_loss:tensor(0.3277, grad_fn=<AddBackward0>) total loss:tensor(72.9872, grad_fn=<AddBackward0>)
# 195 epoch_loss:tensor(0.3276, grad_fn=<AddBackward0>) total loss:tensor(73.3149, grad_fn=<AddBackward0>)
# 196 epoch_loss:tensor(0.3275, grad_fn=<AddBackward0>) total loss:tensor(73.6424, grad_fn=<AddBackward0>)
# 197 epoch_loss:tensor(0.3274, grad_fn=<AddBackward0>) total loss:tensor(73.9698, grad_fn=<AddBackward0>)
# 198 epoch_loss:tensor(0.3273, grad_fn=<AddBackward0>) total loss:tensor(74.2972, grad_fn=<AddBackward0>)
# 199 epoch_loss:tensor(0.3273, grad_fn=<AddBackward0>) total loss:tensor(74.6245, grad_fn=<AddBackward0>)
# 200 epoch_loss:tensor(0.3272, grad_fn=<AddBackward0>) total loss:tensor(74.9516, grad_fn=<AddBackward0>)
# 201 epoch_loss:tensor(0.3271, grad_fn=<AddBackward0>) total loss:tensor(75.2787, grad_fn=<AddBackward0>)
# 202 epoch_loss:tensor(0.3270, grad_fn=<AddBackward0>) total loss:tensor(75.6057, grad_fn=<AddBackward0>)
# 203 epoch_loss:tensor(0.3269, grad_fn=<AddBackward0>) total loss:tensor(75.9326, grad_fn=<AddBackward0>)
# 204 epoch_loss:tensor(0.3268, grad_fn=<AddBackward0>) total loss:tensor(76.2594, grad_fn=<AddBackward0>)
# 205 epoch_loss:tensor(0.3267, grad_fn=<AddBackward0>) total loss:tensor(76.5861, grad_fn=<AddBackward0>)
# 206 epoch_loss:tensor(0.3266, grad_fn=<AddBackward0>) total loss:tensor(76.9127, grad_fn=<AddBackward0>)
# 207 epoch_loss:tensor(0.3265, grad_fn=<AddBackward0>) total loss:tensor(77.2393, grad_fn=<AddBackward0>)
# 208 epoch_loss:tensor(0.3265, grad_fn=<AddBackward0>) total loss:tensor(77.5657, grad_fn=<AddBackward0>)
# 209 epoch_loss:tensor(0.3264, grad_fn=<AddBackward0>) total loss:tensor(77.8921, grad_fn=<AddBackward0>)
# 210 epoch_loss:tensor(0.3263, grad_fn=<AddBackward0>) total loss:tensor(78.2184, grad_fn=<AddBackward0>)
# 211 epoch_loss:tensor(0.3262, grad_fn=<AddBackward0>) total loss:tensor(78.5446, grad_fn=<AddBackward0>)
# 212 epoch_loss:tensor(0.3261, grad_fn=<AddBackward0>) total loss:tensor(78.8708, grad_fn=<AddBackward0>)
# 213 epoch_loss:tensor(0.3261, grad_fn=<AddBackward0>) total loss:tensor(79.1968, grad_fn=<AddBackward0>)
# 214 epoch_loss:tensor(0.3260, grad_fn=<AddBackward0>) total loss:tensor(79.5228, grad_fn=<AddBackward0>)
# 215 epoch_loss:tensor(0.3259, grad_fn=<AddBackward0>) total loss:tensor(79.8487, grad_fn=<AddBackward0>)
# 216 epoch_loss:tensor(0.3258, grad_fn=<AddBackward0>) total loss:tensor(80.1745, grad_fn=<AddBackward0>)
# 217 epoch_loss:tensor(0.3257, grad_fn=<AddBackward0>) total loss:tensor(80.5003, grad_fn=<AddBackward0>)
# 218 epoch_loss:tensor(0.3257, grad_fn=<AddBackward0>) total loss:tensor(80.8259, grad_fn=<AddBackward0>)
# 219 epoch_loss:tensor(0.3256, grad_fn=<AddBackward0>) total loss:tensor(81.1515, grad_fn=<AddBackward0>)
# 220 epoch_loss:tensor(0.3255, grad_fn=<AddBackward0>) total loss:tensor(81.4771, grad_fn=<AddBackward0>)
# 221 epoch_loss:tensor(0.3254, grad_fn=<AddBackward0>) total loss:tensor(81.8025, grad_fn=<AddBackward0>)
# 222 epoch_loss:tensor(0.3254, grad_fn=<AddBackward0>) total loss:tensor(82.1279, grad_fn=<AddBackward0>)
# 223 epoch_loss:tensor(0.3253, grad_fn=<AddBackward0>) total loss:tensor(82.4532, grad_fn=<AddBackward0>)
# 224 epoch_loss:tensor(0.3252, grad_fn=<AddBackward0>) total loss:tensor(82.7784, grad_fn=<AddBackward0>)
# 225 epoch_loss:tensor(0.3252, grad_fn=<AddBackward0>) total loss:tensor(83.1035, grad_fn=<AddBackward0>)
# 226 epoch_loss:tensor(0.3251, grad_fn=<AddBackward0>) total loss:tensor(83.4286, grad_fn=<AddBackward0>)
# 227 epoch_loss:tensor(0.3250, grad_fn=<AddBackward0>) total loss:tensor(83.7536, grad_fn=<AddBackward0>)
# 228 epoch_loss:tensor(0.3249, grad_fn=<AddBackward0>) total loss:tensor(84.0786, grad_fn=<AddBackward0>)
# 229 epoch_loss:tensor(0.3249, grad_fn=<AddBackward0>) total loss:tensor(84.4035, grad_fn=<AddBackward0>)
# 230 epoch_loss:tensor(0.3248, grad_fn=<AddBackward0>) total loss:tensor(84.7283, grad_fn=<AddBackward0>)
# 231 epoch_loss:tensor(0.3247, grad_fn=<AddBackward0>) total loss:tensor(85.0530, grad_fn=<AddBackward0>)
# 232 epoch_loss:tensor(0.3247, grad_fn=<AddBackward0>) total loss:tensor(85.3777, grad_fn=<AddBackward0>)
# 233 epoch_loss:tensor(0.3246, grad_fn=<AddBackward0>) total loss:tensor(85.7023, grad_fn=<AddBackward0>)
# 234 epoch_loss:tensor(0.3245, grad_fn=<AddBackward0>) total loss:tensor(86.0268, grad_fn=<AddBackward0>)
# 235 epoch_loss:tensor(0.3245, grad_fn=<AddBackward0>) total loss:tensor(86.3513, grad_fn=<AddBackward0>)
# 236 epoch_loss:tensor(0.3244, grad_fn=<AddBackward0>) total loss:tensor(86.6757, grad_fn=<AddBackward0>)
# 237 epoch_loss:tensor(0.3244, grad_fn=<AddBackward0>) total loss:tensor(87.0001, grad_fn=<AddBackward0>)
# 238 epoch_loss:tensor(0.3243, grad_fn=<AddBackward0>) total loss:tensor(87.3244, grad_fn=<AddBackward0>)
# 239 epoch_loss:tensor(0.3242, grad_fn=<AddBackward0>) total loss:tensor(87.6486, grad_fn=<AddBackward0>)
# 240 epoch_loss:tensor(0.3242, grad_fn=<AddBackward0>) total loss:tensor(87.9728, grad_fn=<AddBackward0>)
# 241 epoch_loss:tensor(0.3241, grad_fn=<AddBackward0>) total loss:tensor(88.2969, grad_fn=<AddBackward0>)
# 242 epoch_loss:tensor(0.3240, grad_fn=<AddBackward0>) total loss:tensor(88.6209, grad_fn=<AddBackward0>)
# 243 epoch_loss:tensor(0.3240, grad_fn=<AddBackward0>) total loss:tensor(88.9449, grad_fn=<AddBackward0>)
# 244 epoch_loss:tensor(0.3239, grad_fn=<AddBackward0>) total loss:tensor(89.2689, grad_fn=<AddBackward0>)
# 245 epoch_loss:tensor(0.3239, grad_fn=<AddBackward0>) total loss:tensor(89.5927, grad_fn=<AddBackward0>)
# 246 epoch_loss:tensor(0.3238, grad_fn=<AddBackward0>) total loss:tensor(89.9165, grad_fn=<AddBackward0>)
# 247 epoch_loss:tensor(0.3238, grad_fn=<AddBackward0>) total loss:tensor(90.2403, grad_fn=<AddBackward0>)
# 248 epoch_loss:tensor(0.3237, grad_fn=<AddBackward0>) total loss:tensor(90.5640, grad_fn=<AddBackward0>)
# 249 epoch_loss:tensor(0.3236, grad_fn=<AddBackward0>) total loss:tensor(90.8876, grad_fn=<AddBackward0>)
# validation loss is equal to: tensor(0.5484, grad_fn=<NllLossBackward0>)
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        16
#            1       0.88      0.88      0.88        16
#
#     accuracy                           0.88        32
#    macro avg       0.88      0.88      0.88        32
# weighted avg       0.88      0.88      0.88        32
